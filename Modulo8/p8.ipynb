# %% [markdown]
# # Modulo 8
# Por Victor Jair Salas

# %%
#Variable de no diccionario
#Solo pueden almacenar un tipo de dato a la vez
name = "Earthsss"
names = ["Earths"]
moons = 1

#Diccionarios son conjuntos de variables relacionadas
#clave : valor

#variable diccionario
planet = {
    #"clave":valor
    "name": "Earth",
    "moons": 1
}
#Imprimir de un diccionario

print(f"{planet.get('name')}")
print("Hola {}".format(planet["name"]))
print(f"Hola {planet['name']}")


#wibble = planet.get('wibble') # Regresa None
#print(wibble)
#wibble = planet['wibble'] # Arroja un KeyError
#print(wibble)

#Cambiar con diccionario.update({clave: valornuevo})
planet.update({"name": "Marte"})
planet.update({"moons": 1})
#Se imprime lo actualizado
print(f"{planet['name']}")
print(f"{planet['moons']}")
#Actualizar con corchetes
planet["name"] = "Jupiter"
planet["moons"] = 64
print(f"{planet['name']}")
print(f"{planet['moons']}")

#Update en una misma llamada
planet.update({
    "name":"Venus",
    "moons": 16
})
#Update con corchetes
planet["name"] = "Venus"
planet["moons"] = 16

#para agregar una nueva clave simplemente declarala
planet["orbita"] = 4333
print(planet)

#para eliminar usa pop
planet.pop("orbita")

print(planet)

planet["diametro (km)"] = {
    "polar": 13333,
    "equatorial": 162343
}
print(planet)

{'name': 'Venus',
 'moons': 16,
 'diametro (km)':
  {'polar': 13333, 
  'equatorial': 162343}
  }

planet1 = {
    "name": "Jupiter",
    "moons" : 64,
    "diametro" :{
        "polar": 16,
        "equatorial": 20
    },
    "visitas":{
        "locales":25,
        "propias":{
            "mias":50,
            "viajeros":{
                "extranjeros":16
            }
        }
    }
}
print(planet1["visitas"]["propias"]["viajeros"]["extranjeros"])

diccionario = {
    "clave" : "valor",
    "keys":"value",
    "diccionario2":{
        "clave2":"valor2",
        "clave3":{
            "clavehola":"hola",
            "rama":{
                "ramados":{
                    "xd":24,
                    "experimentando":{
                        "hastaaqui" : 1
                    }
                }
            }
        }
    }
}
print(diccionario["diccionario2"]["clave3"]["rama"]["ramados"]["experimentando"]["hastaaqui"])
print(diccionario.get("clave"))
# Out:
# Earth
# Hola Earth
# Hola Earth
# Marte
# 1
# Jupiter
# 64
# {'name': 'Venus', 'moons': 16, 'orbita': 4333}
# {'name': 'Venus', 'moons': 16}
# {'name': 'Venus', 'moons': 16, 'diametro (km)': {'polar': 13333, 'equatorial': 162343}}
# 16
# 1
# valor

# %%
#Método Keys
rainfall = {
    "october": 3.5,
    "november": 4.2,
    "december": 2.1
}
for i in rainfall:
    print(rainfall)

for i in rainfall.keys():
    print(f"{i}: {rainfall[i]} cm")

if "december" in rainfall:
    rainfall["december"] = rainfall["december"] + 1
    print(rainfall["december"])
else:
    rainfall["december"] = 1
    print(rainfall["december"])

#Total de precipitaciones 0
total_rainfall = 0

# Para cada valor en los valores de rainfall
for value in rainfall.values():
    
    # El total de las precipitaciones será igual a ese mismo + el valor que se está iterando

    total_rainfall = total_rainfall + value

# Muestra 'Hay un total de precipitaciones (el valor total) en centímetros en el último cuarto (haciendo referencia al cuarto del año)

print(f'There was {total_rainfall}cm in the last quarter')

# Salida:
# There was 10.8cm in the last quarter
# Out:
# {'october': 3.5, 'november': 4.2, 'december': 2.1}
# {'october': 3.5, 'november': 4.2, 'december': 2.1}
# {'october': 3.5, 'november': 4.2, 'december': 2.1}
# october: 3.5 cm
# november: 4.2 cm
# december: 2.1 cm
# 3.1
# There was 10.8cm in the last quarter

# %%
dictprueba = {
    "Genesis" : 17,
    "Dany" : 15,
    "Jair": 20
}
for i in dictprueba.keys():
    print(i)
    print(dictprueba[i])

for i in dictprueba.values():
    print(i)

dictprueba = {
    "Genesis" : 17,
    "Dany" : 15,
    "Jair": 20
}

rainfall = {
    "october": 3.5,
    "november": 4.2,
    "december": 2.1
}

for i in rainfall:
    print(i)

for i in dictprueba.values():
    print(i)
for i in dictprueba:
    print(f"{i}: {dictprueba[i]}")

for i in dictprueba.keys():
    print(f"{i}: {dictprueba[i]}")
# Out:
# Genesis
# 17
# Dany
# 15
# Jair
# 20
# 17
# 15
# 20
# october
# november
# december
# 17
# 15
# 20
# Genesis: 17
# Dany: 15
# Jair: 20
# Genesis: 17
# Dany: 15
# Jair: 20
# dict_items([('hola', 1), ('adios', 2)])

# %%
lista = {
    "hola" : 1,
    "adios" : 2
}
print(lista.items())
for i, j in lista.items():
    print(f"{i}{j}")
# Out:
# dict_items([('hola', 1), ('adios', 2)])
# hola1
# adios2
